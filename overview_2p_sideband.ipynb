# %%
from process import *
from calculate import *
from plots import *
from envelopes import *
from supports import *

import numpy as np
import matplotlib.pyplot as plt

# %%
# TLS, single-tone
wd_red_larger = [1.2728, 1.2821, 1.2974, 1.3474]
shift_red_larger = [0.0455, 0.0641, 0.0948, 0.1948]
wsb_red_larger = [0.0007435, 0.00294, 0.006461, 0.01697]
wd_blue_larger = [5.2716, 5.2781, 5.3032, 5.3452, 5.474]
shift_blue_larger = [0.0432, 0.0561, 0.1064, 0.1905, 0.448]
wsb_blue_larger = [0.0007608, 0.003019, 0.01183, 0.02563, 0.06447]
Omega_larger = [0.05, 0.1, 0.2, 0.3, 0.5]
power_larger = 2*np.asarray(Omega_larger)**2

wd_red_smaller = [1.2566, 1.2402, 1.2135, 1.1337]
shift_red_smaller = [-0.0131, 0.0196, 0.073, 0.2326]
wsb_red_smaller = [0.0004685, 0.001855, 0.004214, 0.01214]
wd_blue_smaller = [5.2312, 5.2108, 5.177, 5.0683]
shift_blue_smaller = [-0.0377, -0.0784, -0.146, -0.3634]
wsb_blue_smaller = [0.001896, 0.007476, 0.01644, 0.04267]
Omega_smaller = [0.1, 0.2, 0.3, 0.5]
power_smaller = 2*np.asarray(Omega_smaller)**2

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
fig.suptitle("TLS, single-tone, $\\Omega_d/2/2\\pi = 0.1 \\rightarrow 0.2 \\rightarrow 0.3 \\rightarrow 0.5$ GHz")
plt.subplot(1, 2, 1)
plt.scatter(shift_red_larger, wsb_red_larger, marker='s', c='r', s=100*np.asarray(Omega_larger))
plt.scatter(shift_blue_larger, wsb_blue_larger, marker='s', c='b', s=100*np.asarray(Omega_larger))
plt.scatter(shift_red_smaller, wsb_red_smaller, marker='o', c='r', s=100*np.asarray(Omega_smaller))
plt.scatter(shift_blue_smaller, wsb_blue_smaller, marker='o', c='b', s=100*np.asarray(Omega_smaller))
plt.plot(shift_red_larger, wsb_red_larger, c='r')
plt.plot(shift_blue_larger, wsb_blue_larger, c='b', label='$\\omega_q > \\omega_c$')
plt.plot(shift_red_smaller, wsb_red_smaller, ':', c='r')
plt.plot(shift_blue_smaller, wsb_blue_smaller, ':', c='b', label='$\\omega_q < \\omega_c$')
plt.ylim([0, 0.07])
plt.xlabel("ac-Stark shift [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.legend()

ax1 = plt.subplot(1, 2, 2)
ax1.scatter(wd_red_larger, wsb_red_larger, marker='s', c='r', s=100*np.asarray(Omega_larger))
ax1.scatter(wd_red_smaller, wsb_red_smaller, marker='o', c='r', s=100*np.asarray(Omega_smaller))
ax1.plot(wd_red_larger, wsb_red_larger, c='r')
ax1.plot(wd_red_smaller, wsb_red_smaller, ':', c='r')
ax1.set_xlabel("$\\omega_d/2\\pi$ [GHz] (red)")
ax1.set_ylim([0, 0.07])
ax2 = ax1.twiny()
ax2.scatter(wd_blue_larger, wsb_blue_larger, marker='s', c='b', s=100*np.asarray(Omega_larger))
ax2.scatter(wd_blue_smaller, wsb_blue_smaller, marker='o', c='b', s=100*np.asarray(Omega_smaller))
ax2.plot(wd_blue_larger, wsb_blue_larger, c='b', label='$\\omega_q > \\omega_c$')
ax2.plot(wd_blue_smaller, wsb_blue_smaller, ':', c='b', label='$\\omega_q < \\omega_c$')
ax2.set_xlabel("$\\omega_d/2\\pi$ [GHz] (blue)")
ax2.tick_params(axis='x')
ax1.set_ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.legend()

plt.tight_layout()
fig.subplots_adjust(top=0.82)
plt.show()

fig, axes = plt.subplots(1, 4, figsize=(12, 4))
plt.subplot(1, 4, 1)
plt.plot(Omega_larger[1:], wsb_red_larger, c='r')
plt.plot(Omega_larger, wsb_blue_larger, c='b', label='$\\omega_q > \\omega_c$')
plt.plot(Omega_smaller, wsb_red_smaller, ':', c='r')
plt.plot(Omega_smaller, wsb_blue_smaller, ':', c='b', label='$\\omega_q < \\omega_c$')
plt.xlim([0, 0.52])
plt.ylim([0, 0.07])
plt.xlabel("$\\Omega_d/2/2\\pi$ [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Amplitude vs. transition frequency")
plt.legend()

plt.subplot(1, 4, 2)
plt.plot(power_larger[1:], wsb_red_larger, c='r')
plt.plot(power_larger, wsb_blue_larger, c='b')
plt.plot(power_smaller, wsb_red_smaller, ':', c='r')
plt.plot(power_smaller, wsb_blue_smaller, ':', c='b')
plt.xlim([0, 0.52])
plt.ylim([0, 0.07])
plt.xlabel("$P$")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Power vs. transition frequency")

plt.subplot(1, 4, 3)
plt.plot(Omega_larger[1:], shift_red_larger, c='r')
plt.plot(Omega_larger, shift_blue_larger, c='b')
plt.plot(Omega_smaller, shift_red_smaller, ':', c='r')
plt.plot(Omega_smaller, shift_blue_smaller, ':', c='b')
plt.xlim([0, 0.52])
plt.ylim([-0.4, 0.5])
plt.xlabel("$\\Omega_d/2/2\\pi$ [GHz]")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Amplitude vs. ac-Stark shift")

plt.subplot(1, 4, 4)
plt.plot(power_larger[1:], shift_red_larger, c='r')
plt.plot(power_larger, shift_blue_larger, c='b')
plt.plot(power_smaller, shift_red_smaller, ':', c='r')
plt.plot(power_smaller, shift_blue_smaller, ':', c='b')
plt.xlim([0, 0.52])
plt.ylim([-0.4, 0.5])
plt.xlabel("$P$")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Power vs. ac-Stark shift")

plt.tight_layout()
plt.show()

shift_red_larger_th = [0.00640, 0.02561, 0.05768, 0.16075]
shift_blue_larger_th = [0.00450, 0.01807, 0.07362, 0.17107, 0.52909]
shift_red_smaller_th = [0.01109, 0.04425, 0.09912, 0.27184]
shift_blue_smaller_th = [-0.01408, -0.05739, -0.13332, -0.41290]

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
plt.suptitle("ac-Stark shift: simulation vs. theory")
plt.subplot(1, 2, 1)
plt.plot([-1,1], [-1,1], '--', c='gray')
plt.scatter(shift_red_larger, shift_red_larger_th, marker='s', c='r', s=100*np.asarray(Omega_larger))
plt.scatter(shift_blue_larger, shift_blue_larger_th, marker='s', c='b', s=100*np.asarray(Omega_larger))
plt.scatter(shift_red_smaller, shift_red_smaller_th, marker='o', c='r', s=100*np.asarray(Omega_smaller))
plt.scatter(shift_blue_smaller, shift_blue_smaller_th, marker='o', c='b', s=100*np.asarray(Omega_smaller))
plt.plot(shift_red_larger, shift_red_larger_th, c='r')
plt.plot(shift_blue_larger, shift_blue_larger_th, c='b', label='$\\omega_q > \\omega_c$')
plt.plot(shift_red_smaller, shift_red_smaller_th, ':', c='r')
plt.plot(shift_blue_smaller, shift_blue_smaller_th, ':', c='b', label='$\\omega_q < \\omega_c$')
plt.xlim([-0.4, 0.5])
plt.ylim([-0.5, 0.6])
plt.xlabel("Simulated [GHz]")
plt.ylabel("Theoretical [GHz]")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot([0, 0.55], [0, 0], '--', c='gray')
plt.scatter(Omega_larger[1:], np.asarray(shift_red_larger_th)-np.asarray(shift_red_larger), marker='s', c='r', s=100*np.asarray(Omega_larger))
plt.scatter(Omega_larger, np.asarray(shift_blue_larger_th)-np.asarray(shift_blue_larger), marker='s', c='b', s=100*np.asarray(Omega_larger))
plt.scatter(Omega_smaller, np.asarray(shift_red_smaller_th)-np.asarray(shift_red_smaller), marker='o', c='r', s=100*np.asarray(Omega_smaller))
plt.scatter(Omega_smaller, np.asarray(shift_blue_smaller_th)-np.asarray(shift_blue_smaller), marker='o', c='b', s=100*np.asarray(Omega_smaller))
plt.plot(Omega_larger[1:], np.asarray(shift_red_larger_th)-np.asarray(shift_red_larger), c='r')
plt.plot(Omega_larger, np.asarray(shift_blue_larger_th)-np.asarray(shift_blue_larger), c='b', label='$\\omega_q > \\omega_c$')
plt.plot(Omega_smaller, np.asarray(shift_red_smaller_th)-np.asarray(shift_red_smaller), ':', c='r')
plt.plot(Omega_smaller, np.asarray(shift_blue_smaller_th)-np.asarray(shift_blue_smaller), ':', c='b', label='$\\omega_q < \\omega_c$')
plt.xlim([0, 0.55])
plt.ylim([-0.06, 0.09])
plt.xlabel("$\\Omega_d/2/2\\pi$ [GHz]")
plt.ylabel("theoretical - simulated [GHz]")
plt.legend()

plt.tight_layout()
fig.subplots_adjust(top=0.92)
plt.show()

# %%
# TLS, single-tone, wq > wc
wd_red = [1.2728, 1.2821, 1.2974, 1.3474]
shift_red = [0.0455, 0.0641, 0.0948, 0.1948]
wsb_red = [0.0007435, 0.00294, 0.006461, 0.01697]
wd_blue = [0.0432, 0.0561, 0.1064, 0.1905, 0.448]
shift_blue = [0.0432, 0.0561, 0.1064, 0.1905, 0.448]
wsb_blue = [0.0007608, 0.003019, 0.01183, 0.02563, 0.06447]
Omega = [0.05, 0.1, 0.2, 0.3, 0.5]
power = 2*np.asarray(Omega)**2

plt.figure(figsize=(6,4))
plt.plot(shift_red, wsb_red, 's', c='r')
plt.plot(shift_blue, wsb_blue, 's', c='b')
for i in range(3):
    plt.arrow(shift_red[i], wsb_red[i], shift_red[i+1]-shift_red[i], wsb_red[i+1]-wsb_red[i],
              width=0.0002, length_includes_head=True, head_length=60*0.0003, head_width=5*0.0003,
              color='r', alpha=0.5)
for i in range(4):
    plt.arrow(shift_blue[i], wsb_blue[i], shift_blue[i+1]-shift_blue[i], wsb_blue[i+1]-wsb_blue[i],
              width=0.0003, length_includes_head=True, head_length=70*0.0003, head_width=7*0.0003,
              color='b', alpha=0.5)
plt.xlabel("ac-Stark shift [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("TLS, single-tone, $\\omega_q > \\omega_c$, $\\Omega_d/2/2\\pi = 0.1 \\rightarrow 0.2 \\rightarrow 0.3 \\rightarrow 0.5$")
plt.show()

fig, axes = plt.subplots(1, 4, figsize=(12, 4))
plt.subplot(1, 4, 1)
plt.plot(Omega[1:], wsb_red, c='r')
plt.plot(Omega, wsb_blue, c='b')
plt.xlabel("$\\Omega_d/2/2\\pi$ [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Amplitude vs. transition frequency")

plt.subplot(1, 4, 2)
plt.plot(power[1:], wsb_red, c='r')
plt.plot(power, wsb_blue, c='b')
plt.xlabel("$P$")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Power vs. transition frequency")

plt.subplot(1, 4, 3)
plt.plot(Omega[1:], shift_red, c='r')
plt.plot(Omega, shift_blue, c='b')
plt.xlabel("$\\Omega_d/2/2\\pi$ [GHz]")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Amplitude vs. ac-Stark shift")

plt.subplot(1, 4, 4)
plt.plot(power[1:], shift_red, c='r')
plt.plot(power, shift_blue, c='b')
plt.xlabel("$P$")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Power vs. ac-Stark shift")

plt.tight_layout()
plt.show()

# %%
# TLS, single-tone, wq < wc
wd_red = [1.2566, 1.2402, 1.2135, 1.1337]
shift_red = [-0.0131, 0.0196, 0.073, 0.2326]
wsb_red = [0.0004685, 0.001855, 0.004214, 0.01214]
wd_blue = [5.2312, 5.2108, 5.177, 5.0683]
shift_blue = [-0.0377, -0.0784, -0.146, -0.3634]
wsb_blue = [0.001896, 0.007476, 0.01644, 0.04267]
Omega = [0.1, 0.2, 0.3, 0.5]
power = 2*np.asarray(Omega)**2

plt.figure(figsize=[6,4])
plt.plot(shift_red, wsb_red, 'o', c='r')
plt.plot(shift_blue, wsb_blue, 'o', c='b')
for i in range(3):
    plt.arrow(shift_red[i], wsb_red[i], shift_red[i+1]-shift_red[i], wsb_red[i+1]-wsb_red[i],
              width=0.0002, length_includes_head=True, head_length=80*0.0003, head_width=5*0.0003,
              color='r', alpha=0.5)
    plt.arrow(shift_blue[i], wsb_blue[i], shift_blue[i+1]-shift_blue[i], wsb_blue[i+1]-wsb_blue[i],
              width=0.0003, length_includes_head=True, head_length=70*0.0003, head_width=7*0.0003,
              color='b', alpha=0.5)
plt.xlabel("ac-Stark shift [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("TLS, single-tone, $\\omega_q < \\omega_c$, $\\Omega_d/2/2\\pi = 0.1 \\rightarrow 0.2 \\rightarrow 0.3 \\rightarrow 0.5$")
plt.show()

fig, axes = plt.subplots(1, 4, figsize=(12, 4))
plt.subplot(1, 4, 1)
plt.plot(Omega, wsb_red, ':', c='r')
plt.plot(Omega, wsb_blue, ':', c='b')
plt.xlabel("$\\Omega_d/2/2\\pi$ [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Amplitude vs. transition frequency")

plt.subplot(1, 4, 2)
plt.plot(power, wsb_red, ':', c='r')
plt.plot(power, wsb_blue, ':', c='b')
plt.xlabel("$P$")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Power vs. transition frequency")

plt.subplot(1, 4, 3)
plt.plot(Omega, shift_red, ':', c='r')
plt.plot(Omega, shift_blue, ':', c='b')
plt.xlabel("$\\Omega_d/2/2\\pi$ [GHz]")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Amplitude vs. ac-Stark shift")

plt.subplot(1, 4, 4)
plt.plot(power, shift_red, ':', c='r')
plt.plot(power, shift_blue, ':', c='b')
plt.xlabel("$P$")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Power vs. ac-Stark shift")

plt.tight_layout()
plt.show()

# %%
# TLS, double-tone, wq > wc, dw = [0.2, 0.5]
shift_red = [0.13439, 0.1248]
wsb_red = [0.01421, 0.006069]
shift_blue = [0.1235, 0.1204]
wsb_blue = [0.01308, 0.004875]

plt.figure(figsize=[4,4])
plt.plot(shift_red, wsb_red, 'o', c='r')
plt.plot(shift_blue, wsb_blue, 'o', c='b')
for i in range(1):
    plt.arrow(shift_red[i], wsb_red[i], shift_red[i+1]-shift_red[i], wsb_red[i+1]-wsb_red[i],
              width=0.00015, length_includes_head=True, head_length=3*0.0003, head_width=2*0.0003,
              color='r', alpha=0.5)
    plt.arrow(shift_blue[i], wsb_blue[i], shift_blue[i+1]-shift_blue[i], wsb_blue[i+1]-wsb_blue[i],
              width=0.00015, length_includes_head=True, head_length=3*0.0003, head_width=2*0.0003,
              color='b', alpha=0.5)
plt.xlabel("ac-Stark shift [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("TLS, single-tone, $\\omega_q > \\omega_c$, $\\delta/2\\pi = 0.2 \\rightarrow 0.5$ GHz")
plt.show()

# %%
# Transmon, single-tone
wd_red_larger = [1.1823, 1.1811, 1.1777, 1.1728]
shift_red_larger = [-0.1354, -0.1379, -0.1446, -0.1545]
wsb_red_larger = [0.0003968, 0.001112, 0.002199]
wd_blue_larger = [5.1574, 5.1423, 5.1106, 5.059]
shift_blue_larger = [-0.1852, -0.2154, -0.2789,-0.382]
wsb_blue_larger = [0.00326, 0.009515, 0.01976]
Omega_larger = [0.1, 0.3, 0.5, 0.7]
power_larger = 2*np.asarray(Omega_larger)**2

wd_red_smaller = [1.3616, 1.3756, 1.399]
shift_red_smaller = [-0.2225, -0.2511, -0.2979]
wsb_red_smaller = [0.0008842, 0.002476, 0.004971]
wd_blue_smaller = [5.1508, 5.1395, 5.1217]
shift_blue_smaller = [-0.1984, -0.221, -0.2567]
wsb_blue_smaller = [0.0007729, 0.002221, 0.004259]
Omega_smaller = [0.3, 0.5, 0.7]
power_smaller = 2*np.asarray(Omega_smaller)**2

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
fig.suptitle("Transmon, single-tone, $\\Omega_d/2/2\\pi = 0.3 \\rightarrow 0.5 \\rightarrow 0.7$")
plt.subplot(1, 2, 1)
plt.scatter(shift_red_larger[1:], wsb_red_larger, marker='s', c='r', s=100*np.asarray(Omega_larger))
plt.scatter(shift_blue_larger[1:], wsb_blue_larger, marker='s', c='b', s=100*np.asarray(Omega_larger))
plt.scatter(shift_red_smaller, wsb_red_smaller, marker='o', c='r', s=100*np.asarray(Omega_smaller))
plt.scatter(shift_blue_smaller, wsb_blue_smaller, marker='o', c='b', s=100*np.asarray(Omega_smaller))
plt.plot(shift_red_larger[1:], wsb_red_larger, c='r')
plt.plot(shift_blue_larger[1:], wsb_blue_larger, c='b', label='$\\omega_q > \\omega_c$')
plt.plot(shift_red_smaller, wsb_red_smaller, ':', c='r')
plt.plot(shift_blue_smaller, wsb_blue_smaller, ':', c='b', label='$\\omega_q < \\omega_c$')
plt.ylim([0, 0.021])
plt.xlabel("ac-Stark shift [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.legend()

ax1 = plt.subplot(1, 2, 2)
ax1.scatter(wd_red_larger[1:], wsb_red_larger, marker='s', c='r', s=100*np.asarray(Omega_larger))
ax1.scatter(wd_red_smaller, wsb_red_smaller, marker='o', c='r', s=100*np.asarray(Omega_smaller))
ax1.plot(wd_red_larger[1:], wsb_red_larger, c='r')
ax1.plot(wd_red_smaller, wsb_red_smaller, ':', c='r')
ax1.set_xlabel("$\\omega_d/2\\pi$ [GHz] (red)")
ax1.set_ylim([0, 0.021])
ax2 = ax1.twiny()
ax2.scatter(wd_blue_larger[1:], wsb_blue_larger, marker='s', c='b', s=100*np.asarray(Omega_larger))
ax2.scatter(wd_blue_smaller, wsb_blue_smaller, marker='o', c='b', s=100*np.asarray(Omega_smaller))
ax2.plot(wd_blue_larger[1:], wsb_blue_larger, c='b', label='$\\omega_q > \\omega_c$')
ax2.plot(wd_blue_smaller, wsb_blue_smaller, ':', c='b', label='$\\omega_q < \\omega_c$')

ax2.set_xlabel("$\\omega_d/2\\pi$ [GHz] (blue)")
ax2.tick_params(axis='x')
ax1.set_ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.legend()

plt.tight_layout()
fig.subplots_adjust(top=0.84)
plt.show()

fig, axes = plt.subplots(1, 4, figsize=(12, 4))
plt.subplot(1, 4, 1)
plt.plot(Omega_larger[1:], wsb_red_larger, c='r')
plt.plot(Omega_larger[1:], wsb_blue_larger, c='b', label='$\\omega_q > \\omega_c$')
plt.plot(Omega_smaller, wsb_red_smaller, ':', c='r')
plt.plot(Omega_smaller, wsb_blue_smaller, ':', c='b', label='$\\omega_q < \\omega_c$')
plt.xlim([0.2, 0.75])
plt.ylim([0, 0.02])
plt.xlabel("$\\Omega_d/2/2\\pi$ [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Amplitude vs. transition frequency")
plt.legend()

plt.subplot(1, 4, 2)
plt.plot(power_larger[1:], wsb_red_larger, c='r')
plt.plot(power_larger[1:], wsb_blue_larger, c='b')
plt.plot(power_smaller, wsb_red_smaller, ':', c='r')
plt.plot(power_smaller, wsb_blue_smaller, ':', c='b')
plt.xlim([0, 1])
plt.ylim([0, 0.02])
plt.xlabel("$P$")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Power vs. transition frequency")

plt.subplot(1, 4, 3)
plt.plot(Omega_larger, shift_red_larger, c='r')
plt.plot(Omega_larger, shift_blue_larger, c='b')
plt.plot(Omega_smaller, shift_red_smaller, ':', c='r')
plt.plot(Omega_smaller, shift_blue_smaller, ':', c='b')
plt.xlim([0, 0.75])
plt.ylim([-0.1, -0.4])
plt.xlabel("$\\Omega_d/2/2\\pi$ [GHz]")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Amplitude vs. ac-Stark shift")

plt.subplot(1, 4, 4)
plt.plot(power_larger, shift_red_larger, c='r')
plt.plot(power_larger, shift_blue_larger, c='b')
plt.plot(power_smaller, shift_red_smaller, ':', c='r')
plt.plot(power_smaller, shift_blue_smaller, ':', c='b')
plt.xlim([0, 1])
plt.ylim([-0.1, -0.4])
plt.xlabel("$P$")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Power vs. ac-Stark shift")

plt.tight_layout()
plt.show()

# %%
# Transmon, single-tone, wq > wc, Omega vs. wsb
wd_red = [1.1823, 1.1811, 1.1777, 1.1728]
shift_red = [-0.1354, -0.1379, -0.1446, -0.1545]
wsb_red = [0.0003968, 0.001112, 0.002199]
wd_blue = [5.1574, 5.1423, 5.1106, 5.059]
shift_blue = [-0.1852, -0.2154, -0.2789,-0.382]
wsb_blue = [0.00326, 0.009515, 0.01976]
Omega = [0.1, 0.3, 0.5, 0.7]
power = 2*np.asarray(Omega_larger)**2

plt.figure(figsize=[6,4])
plt.plot(shift_red[1:], wsb_red, 's', c='r')
plt.plot(shift_blue[1:], wsb_blue, 's', c='b')
for i in range(2):
    plt.arrow(shift_red[i+1], wsb_red[i], shift_red[i+2]-shift_red[i+1], wsb_red[i+1]-wsb_red[i],
              width=0.0002, length_includes_head=True, head_length=20*0.0003, head_width=2*0.0003,
              color='r', alpha=0.5)
    plt.arrow(shift_blue[i+1], wsb_blue[i], shift_blue[i+2]-shift_blue[i+1], wsb_blue[i+1]-wsb_blue[i],
              width=0.0003, length_includes_head=True, head_length=40*0.0003, head_width=4*0.0003,
              color='b', alpha=0.5)
plt.xlabel("ac-Stark shift [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Transmon, single-tone, $\\omega_q > \\omega_c$, $\\Omega_d/2 = 0.3 \\rightarrow 0.5 \\rightarrow 0.7$")
plt.show()

fig, axes = plt.subplots(1, 4, figsize=(12, 4))
plt.subplot(1, 4, 1)
plt.plot(Omega[1:], wsb_red, c='r')
plt.plot(Omega[1:], wsb_blue, c='b')
plt.xlabel("$\\Omega_d/2/2\\pi$ [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Amplitude vs. transition frequency")

plt.subplot(1, 4, 2)
plt.plot(power[1:], wsb_red, c='r')
plt.plot(power[1:], wsb_blue, c='b')
plt.xlabel("$P$")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Power vs. transition frequency")

plt.subplot(1, 4, 3)
plt.plot(Omega, shift_red, c='r')
plt.plot(Omega, shift_blue, c='b')
plt.xlabel("$\\Omega_d/2/2\\pi$ [GHz]")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Amplitude vs. ac-Stark shift")

plt.subplot(1, 4, 4)
plt.plot(power, shift_red, c='r')
plt.plot(power, shift_blue, c='b')
plt.xlabel("$P$")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Power vs. ac-Stark shift")

plt.tight_layout()
plt.show()

# %%
# Transmon, single-tone, wq < wc
wd_red = [1.3616, 1.3756, 1.3426]
shift_red = [-0.2225, -0.2511, -0.2979]
wsb_red = [0.0008842, 0.002476, 0.004971]
wd_blue = [5.1508, 5.1395, 5.1217]
shift_blue = [-0.1984, -0.221, -0.2567]
wsb_blue = [0.0007729, 0.002221, 0.004259]
Omega = [0.3, 0.5, 0.7]
power = 2*np.asarray(Omega)**2

plt.figure(figsize=[6,4])
plt.plot(shift_red, wsb_red, 'o', c='r')
plt.plot(shift_blue, wsb_blue, 'o', c='b')
for i in range(2):
    plt.arrow(shift_red[i], wsb_red[i], shift_red[i+1]-shift_red[i], wsb_red[i+1]-wsb_red[i],
              width=0.00005, length_includes_head=True, head_length=12*0.0003, head_width=0.0003,
              color='r', alpha=0.5)
    plt.arrow(shift_blue[i], wsb_blue[i], shift_blue[i+1]-shift_blue[i], wsb_blue[i+1]-wsb_blue[i],
              width=0.00005, length_includes_head=True, head_length=12*0.0003, head_width=0.0003,
              color='b', alpha=0.5)
plt.xlabel("ac-Stark shift [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Transmon, single-tone, $\\omega_q < \\omega_c$, $\\Omega_d/2/2\\pi = 0.3 \\rightarrow 0.5 \\rightarrow 0.7$")
plt.show()

fig, axes = plt.subplots(1, 4, figsize=(12, 4))
plt.subplot(1, 4, 1)
plt.plot(Omega, wsb_red, ':', c='r')
plt.plot(Omega, wsb_blue, ':', c='b')
plt.xlabel("$\\Omega_d/2/2\\pi$ [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Amplitude vs. transition frequency")

plt.subplot(1, 4, 2)
plt.plot(power, wsb_red, ':', c='r')
plt.plot(power, wsb_blue, ':', c='b')
plt.xlabel("$P$")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Power vs. transition frequency")

plt.subplot(1, 4, 3)
plt.plot(Omega, shift_red, ':', c='r')
plt.plot(Omega, shift_blue, ':', c='b')
plt.xlabel("$\\Omega_d/2/2\\pi$ [GHz]")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Amplitude vs. ac-Stark shift")

plt.subplot(1, 4, 4)
plt.plot(power, shift_red, ':', c='r')
plt.plot(power, shift_blue, ':', c='b')
plt.xlabel("$P$")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Power vs. ac-Stark shift")

plt.tight_layout()
plt.show()

# %%
# TLS, double-tone
wdq_red_larger = [6.061, 6.1248, 6.3668, 6.5352, 6.7317]
shift_red_larger = [0.06102, 0.1248, 0.3668, 0.5352, 0.731]
wsb_red_larger = [0.001583, 0.006069, 0.02078, 0.02991, 0.03817]
wdq_blue_larger = [7.0595, 7.1204, 7.3519, 7.5146, 7.7032]
shift_blue_larger = [0.05954, 0.1204, 0.3519, 0.5146, 0.7032]
wsb_blue_larger = [0.001265, 0.004875, 0.01704, 0.02437, 0.03182]
Omfac_larger = [0.5, 1, 2, 2.5, 3]
Omegaq_larger = 0.025*np.asarray(Omfac_larger)
Omegac_larger = 0.317*np.asarray(Omfac_larger)
power_larger = 2*np.asarray(Omegaq_larger)**2 + 2*np.asarray(Omegac_larger)**2

wdq_red_smaller = [3.4568, 3.4015, 3.1939, 3.0511, 2.8873]
shift_red_smaller = [-0.0432, -0.0985, -0.3061, -0.4489, -0.6127]
wsb_red_smaller = [0.00099, 0.003829, 0.01349, 0.01965, 0.0258]
wdq_blue_smaller = [4.4558, 4.3964, 4.1747, 4.0864, 4.0549, 4.0229, 3.9894, 3.9566, 3.8518]
shift_blue_smaller = [-0.0442, -0.1036, -0.3253, -0.4136, -0.4451, -0.4771, -0.5106, -0.5434, -0.6482]
wsb_blue_smaller = [0.00117, 0.00446, 0.01521, 0.01891, 0.02016, 0.02149, 0.02255, 0.02418, 0.02817]
Omfac_smaller_red = [0.5, 1, 2, 2.5, 3]
Omfac_smaller_blue = [0.5, 1, 2, 2.3, 2.4, 2.5, 2.6, 2.7, 3]
Omegaq_smaller_red = 0.025*np.asarray(Omfac_smaller_red)
Omegac_smaller_red = 0.317*np.asarray(Omfac_smaller_red)
Omegaq_smaller_blue = 0.025*np.asarray(Omfac_smaller_blue)
Omegac_smaller_blue = 0.317*np.asarray(Omfac_smaller_blue)
power_smaller_red = 2*np.asarray(Omegaq_smaller_red)**2 + 2*np.asarray(Omegac_smaller_red)**2
power_smaller_blue = 2*np.asarray(Omegaq_smaller_blue)**2 + 2*np.asarray(Omegac_smaller_blue)**2

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
fig.suptitle("TLS, double-tone, $\\Omega_q/2/2\\pi = 0.0125 \\rightarrow 0.025 \\rightarrow 0.05 \\rightarrow 0.0625 \\rightarrow 0.075$ GHz")
plt.subplot(1, 2, 1)
plt.scatter(shift_red_larger, wsb_red_larger, marker='s', c='r', s=20*np.asarray(Omfac_larger))
plt.scatter(shift_blue_larger, wsb_blue_larger, marker='s', c='b', s=20*np.asarray(Omfac_larger))
plt.scatter(shift_red_smaller, wsb_red_smaller, marker='o', c='r', s=20*np.asarray(Omfac_smaller_red))
plt.scatter(shift_blue_smaller, wsb_blue_smaller, marker='o', c='b', s=20*np.asarray(Omfac_smaller_blue))
plt.plot(shift_red_larger, wsb_red_larger, c='r')
plt.plot(shift_blue_larger, wsb_blue_larger, c='b', label='$\\omega_q > \\omega_c$')
plt.plot(shift_red_smaller, wsb_red_smaller, ':', c='r')
plt.plot(shift_blue_smaller, wsb_blue_smaller, ':', c='b', label='$\\omega_q < \\omega_c$')
plt.ylim([0, 0.04])
plt.xlabel("ac-Stark shift [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.legend()

plt.subplot(1, 2, 2)
plt.scatter(wdq_red_larger, wsb_red_larger, marker='s', c='r', s=20*np.asarray(Omfac_larger))
plt.scatter(wdq_blue_larger, wsb_blue_larger, marker='s', c='b', s=20*np.asarray(Omfac_larger))
plt.scatter(wdq_red_smaller, wsb_red_smaller, marker='o', c='r', s=20*np.asarray(Omfac_smaller_red))
plt.scatter(wdq_blue_smaller, wsb_blue_smaller, marker='o', c='b', s=20*np.asarray(Omfac_smaller_blue))
plt.plot(wdq_red_larger, wsb_red_larger, c='r')
plt.plot(wdq_blue_larger, wsb_blue_larger, c='b', label='$\\omega_q > \\omega_c$')
plt.plot(wdq_red_smaller, wsb_red_smaller, ':', c='r')
plt.plot(wdq_blue_smaller, wsb_blue_smaller, ':', c='b', label='$\\omega_q < \\omega_c$')
plt.ylim([0, 0.04])
plt.xlabel("$\\omega_d/2\\pi$ [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.legend()

plt.tight_layout()
fig.subplots_adjust(top=0.88)
plt.show()

fig, axes = plt.subplots(1, 4, figsize=(12, 4))
plt.subplot(1, 4, 1)
plt.plot(Omegaq_larger, wsb_red_larger, c='r')
plt.plot(Omegaq_larger, wsb_blue_larger, c='b', label='$\\omega_q > \\omega_c$')
plt.plot(Omegaq_smaller_red, wsb_red_smaller, ':', c='r')
plt.plot(Omegaq_smaller_blue, wsb_blue_smaller, ':', c='b', label='$\\omega_q < \\omega_c$')
plt.xlim([0, 0.08])
plt.ylim([0, 0.04])
plt.xlabel("$\\Omega_q/2/2\\pi$ [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Amplitude vs. transition frequency")
plt.legend()

plt.subplot(1, 4, 2)
plt.plot(power_larger, wsb_red_larger, c='r')
plt.plot(power_larger, wsb_blue_larger, c='b')
plt.plot(power_smaller_red, wsb_red_smaller, ':', c='r')
plt.plot(power_smaller_blue, wsb_blue_smaller, ':', c='b')
plt.xlim([0, 2])
plt.ylim([0, 0.04])
plt.xlabel("$P$")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Power vs. transition frequency")

plt.subplot(1, 4, 3)
plt.plot(Omegaq_larger, shift_red_larger, c='r')
plt.plot(Omegaq_larger, shift_blue_larger, c='b')
plt.plot(Omegaq_smaller_red, shift_red_smaller, ':', c='r')
plt.plot(Omegaq_smaller_blue, shift_blue_smaller, ':', c='b')
plt.xlim([0, 0.08])
plt.ylim([-0.7, 0.8])
plt.xlabel("$\\Omega_q/2/2\\pi$ [GHz]")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Amplitude vs. ac-Stark shift")

plt.subplot(1, 4, 4)
plt.plot(power_larger, shift_red_larger, c='r')
plt.plot(power_larger, shift_blue_larger, c='b')
plt.plot(power_smaller_red, shift_red_smaller, ':', c='r')
plt.plot(power_smaller_blue, shift_blue_smaller, ':', c='b')
plt.xlim([0, 2])
plt.ylim([-0.7, 0.8])
plt.xlabel("$P$")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Power vs. ac-Stark shift")

plt.tight_layout()
plt.show()

shift_red_larger_th = [0.02251, 0.09052, 0.38629, 0.32297, 0.73611]
shift_blue_larger_th = [0.02124, 0.08517, 0.34285, 0.53717, 0.77526]
shift_red_smaller_th = [-0.01948, -0.07813, -0.31467, -0.49310, -0.71178]
shift_blue_smaller_th = [-0.02075, -0.08340, -0.34957, -0.50099, -0.59331, -0.84263, 0.25478, -0.37494, -0.64618]

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
plt.suptitle("ac-Stark shift: simulation vs. theory")
plt.subplot(1, 2, 1)
plt.plot([-1,1], [-1,1], '--', c='gray')
plt.scatter(shift_red_larger, shift_red_larger_th, marker='s', c='r', s=20*np.asarray(Omfac_larger))
plt.scatter(shift_blue_larger, shift_blue_larger_th, marker='s', c='b', s=20*np.asarray(Omfac_larger))
plt.scatter(shift_red_smaller, shift_red_smaller_th, marker='o', c='r', s=20*np.asarray(Omfac_smaller_red))
plt.scatter(shift_blue_smaller, shift_blue_smaller_th, marker='o', c='b', s=20*np.asarray(Omfac_smaller_blue))
plt.plot(shift_red_larger, shift_red_larger_th, c='r')
plt.plot(shift_blue_larger, shift_blue_larger_th, c='b', label='$\\omega_q > \\omega_c$')
plt.plot(shift_red_smaller, shift_red_smaller_th, ':', c='r')
plt.plot(shift_blue_smaller, shift_blue_smaller_th, ':', c='b', label='$\\omega_q < \\omega_c$')
plt.xlim([-0.7, 0.8])
plt.ylim([-1, 0.85])
plt.xlabel("Simulated [GHz]")
plt.ylabel("Theoretical [GHz]")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot([0, 0.08], [0, 0], '--', c='gray')
plt.scatter(Omegaq_larger, np.asarray(shift_red_larger_th)-np.asarray(shift_red_larger), marker='s', c='r', s=20*np.asarray(Omfac_larger))
plt.scatter(Omegaq_larger, np.asarray(shift_blue_larger_th)-np.asarray(shift_blue_larger), marker='s', c='b', s=20*np.asarray(Omfac_larger))
plt.scatter(Omegaq_smaller_red, np.asarray(shift_red_smaller_th)-np.asarray(shift_red_smaller), marker='o', c='r', s=20*np.asarray(Omfac_smaller_red))
plt.scatter(Omegaq_smaller_blue, np.asarray(shift_blue_smaller_th)-np.asarray(shift_blue_smaller), marker='o', c='b', s=20*np.asarray(Omfac_smaller_blue))
plt.plot(Omegaq_larger, np.asarray(shift_red_larger_th)-np.asarray(shift_red_larger), c='r')
plt.plot(Omegaq_larger, np.asarray(shift_blue_larger_th)-np.asarray(shift_blue_larger), c='b', label='$\\omega_q > \\omega_c$')
plt.plot(Omegaq_smaller_red, np.asarray(shift_red_smaller_th)-np.asarray(shift_red_smaller), ':', c='r')
plt.plot(Omegaq_smaller_blue, np.asarray(shift_blue_smaller_th)-np.asarray(shift_blue_smaller), ':', c='b', label='$\\omega_q < \\omega_c$')
plt.xlim([0, 0.08])
plt.xlabel("$\\Omega_q/2$ $/2\\pi$ [GHz]")
plt.ylabel("theoretical - simulated [GHz]")
plt.legend()

plt.tight_layout()
fig.subplots_adjust(top=0.92)
plt.show()

# %%
# TLS, double-tone, wq > wc
wdq_red = [6.061, 6.1248, 6.3668, 6.5352, 6.7317]
shift_red = [0.06102, 0.1248, 0.3668, 0.5352, 0.731]
wsb_red = [0.001583, 0.006069, 0.02078, 0.02991, 0.03817]
wdq_blue = [7.0595, 7.1204, 7.3519, 7.5146, 7.7032]
shift_blue = [0.05954, 0.1204, 0.3519, 0.5146, 0.7032]
wsb_blue = [0.001265, 0.004875, 0.01704, 0.02437, 0.03182]
Omfac = [0.5, 1, 2, 2.5, 3]
Omegaq = 0.025*np.asarray(Omfac)
Omegac = 0.317*np.asarray(Omfac)
power = 2*np.asarray(Omegaq)**2 + 2*np.asarray(Omegac)**2

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
fig.suptitle("TLS, double-tone, $\\omega_q > \\omega_c$, $\\Omega_q/2/2\\pi = 0.0125 \\rightarrow 0.025 \\rightarrow 0.05 \\rightarrow 0.0625 \\rightarrow 0.075$ GHz")
plt.subplot(1, 2, 1)
plt.plot(shift_red, wsb_red, 's', c='r')
plt.plot(shift_blue, wsb_blue, 's', c='b')
for i in range(4):
    plt.arrow(shift_red[i], wsb_red[i], shift_red[i+1]-shift_red[i], wsb_red[i+1]-wsb_red[i],
              width=0.0002, length_includes_head=True, head_length=100*0.0003, head_width=5*0.0003,
              color='r', alpha=0.5)
for i in range(4):
    plt.arrow(shift_blue[i], wsb_blue[i], shift_blue[i+1]-shift_blue[i], wsb_blue[i+1]-wsb_blue[i],
              width=0.0003, length_includes_head=True, head_length=100*0.0003, head_width=5*0.0003,
              color='b', alpha=0.5)
plt.xlabel("ac-Stark shift [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")

plt.subplot(1, 2, 2)
plt.plot(wdq_red, wsb_red, 's', c='r')
plt.plot(wdq_blue, wsb_blue, 's', c='b')
for i in range(4):
    plt.arrow(wdq_red[i], wsb_red[i], wdq_red[i+1]-wdq_red[i], wsb_red[i+1]-wsb_red[i],
              width=0.0002, length_includes_head=True, head_length=150*0.0003, head_width=8*0.0003,
              color='r', alpha=0.5)
for i in range(4):
    plt.arrow(wdq_blue[i], wsb_blue[i], wdq_blue[i+1]-wdq_blue[i], wsb_blue[i+1]-wsb_blue[i],
              width=0.0003, length_includes_head=True, head_length=150*0.0003, head_width=8*0.0003,
              color='b', alpha=0.5)
plt.xlabel("$\\Omega_q/2\\pi$ [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")

plt.tight_layout()
fig.subplots_adjust(top=0.88)
plt.show()

fig, axes = plt.subplots(1, 4, figsize=(12, 4))
plt.subplot(1, 4, 1)
plt.plot(Omegaq, wsb_red, c='r')
plt.plot(Omegaq, wsb_blue, c='b')
plt.xlabel("$\\Omega_q/2/2\\pi$ [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Amplitude vs. transition frequency")

plt.subplot(1, 4, 2)
plt.plot(power, wsb_red, c='r')
plt.plot(power, wsb_blue, c='b')
plt.xlabel("$P$")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Power vs. transition frequency")

plt.subplot(1, 4, 3)
plt.plot(Omegaq, shift_red, c='r')
plt.plot(Omegaq, shift_blue, c='b')
plt.xlabel("$\\Omega_q/2/2\\pi$ [GHz]")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Amplitude vs. ac-Stark shift")

plt.subplot(1, 4, 4)
plt.plot(power, shift_red, c='r')
plt.plot(power, shift_blue, c='b')
plt.xlabel("$P$")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Power vs. ac-Stark shift")

plt.tight_layout()
plt.show()

# %%
# TLS, double-tone, wq < wc
wdq_red = [3.4568, 3.4015, 3.1939, 3.0511, 2.8873]
shift_red = [-0.0432, -0.0985, -0.3061, -0.4489, -0.6127]
wsb_red = [0.00099, 0.003829, 0.01349, 0.01965, 0.0258]
wdq_blue = [4.4558, 4.3964, 4.1747, 4.0229, 3.8518]
shift_blue = [-0.0442, -0.1036, -0.3253, -0.4771, -0.6482]
wsb_blue = [0.00117, 0.00446, 0.01521, 0.02149, 0.02817]
Omfac = [0.5, 1, 2, 2.5, 3]
Omegaq = 0.025*np.asarray(Omfac)
Omegac = 0.317*np.asarray(Omfac)
power = 2*np.asarray(Omegaq)**2 + 2*np.asarray(Omegac)**2

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
fig.suptitle("TLS, double-tone, $\\omega_q < \\omega_c$, $\\Omega_q/2/2\\pi = 0.0125 \\rightarrow 0.025 \\rightarrow 0.05 \\rightarrow 0.0625 \\rightarrow 0.075$ GHz")
plt.subplot(1, 2, 1)
plt.plot(shift_red, wsb_red, 's', c='r')
plt.plot(shift_blue, wsb_blue, 's', c='b')
for i in range(4):
    plt.arrow(shift_red[i], wsb_red[i], shift_red[i+1]-shift_red[i], wsb_red[i+1]-wsb_red[i],
              width=0.0002, length_includes_head=True, head_length=80*0.0003, head_width=5*0.0003,
              color='r', alpha=0.5)
for i in range(4):
    plt.arrow(shift_blue[i], wsb_blue[i], shift_blue[i+1]-shift_blue[i], wsb_blue[i+1]-wsb_blue[i],
              width=0.0003, length_includes_head=True, head_length=80*0.0003, head_width=5*0.0003,
              color='b', alpha=0.5)
plt.xlabel("ac-Stark shift [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")

plt.subplot(1, 2, 2)
plt.plot(wdq_red, wsb_red, 's', c='r')
plt.plot(wdq_blue, wsb_blue, 's', c='b')
for i in range(4):
    plt.arrow(wdq_red[i], wsb_red[i], wdq_red[i+1]-wdq_red[i], wsb_red[i+1]-wsb_red[i],
              width=0.0002, length_includes_head=True, head_length=200*0.0003, head_width=5*0.0003,
              color='r', alpha=0.5)
for i in range(4):
    plt.arrow(wdq_blue[i], wsb_blue[i], wdq_blue[i+1]-wdq_blue[i], wsb_blue[i+1]-wsb_blue[i],
              width=0.0003, length_includes_head=True, head_length=200*0.0003, head_width=5*0.0003,
              color='b', alpha=0.5)
plt.xlabel("$\\Omega_q/2\\pi$ [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")

plt.tight_layout()
fig.subplots_adjust(top=0.88)
plt.show()

fig, axes = plt.subplots(1, 4, figsize=(12, 4))
plt.subplot(1, 4, 1)
plt.plot(Omegaq, wsb_red, ':', c='r')
plt.plot(Omegaq, wsb_blue, ':', c='b')
plt.xlabel("$\\Omega_q/2/2\\pi$ [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Amplitude vs. transition frequency")

plt.subplot(1, 4, 2)
plt.plot(power, wsb_red, ':', c='r')
plt.plot(power, wsb_blue, ':', c='b')
plt.xlabel("$P$")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Power vs. transition frequency")

plt.subplot(1, 4, 3)
plt.plot(Omegaq, shift_red, ':', c='r')
plt.plot(Omegaq, shift_blue, ':', c='b')
plt.xlabel("$\\Omega_q/2/2\\pi$ [GHz]")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Amplitude vs. ac-Stark shift")

plt.subplot(1, 4, 4)
plt.plot(power, shift_red, ':', c='r')
plt.plot(power, shift_blue, ':', c='b')
plt.xlabel("$P$")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Power vs. ac-Stark shift")

plt.tight_layout()
plt.show()

# %%
# TLS, double-tone
wdq_red_larger = [5.8551, 5.8217, 5.7605]
shift_red_larger = [-0.1449, -0.1783, -0.2395]
wsb_red_larger = [0.0006958, 0.00287, 0.00696]
wdq_blue_larger = [6.8086, 6.778, 6.7234]
shift_blue_larger = [-0.1914, -0.222, -0.2766]
wsb_blue_larger = [0.0006503, 0.002736, 0.006677]
Omfac_larger = [1, 2, 3]
Omegaq_larger = 0.025*np.asarray(Omfac_larger)
Omegac_larger = 0.317*np.asarray(Omfac_larger)
power_larger = 2*np.asarray(Omegaq_larger)**2 + 2*np.asarray(Omegac_larger)**2

wdq_red_smaller = [3.2777, 3.2662, 3.2346]
shift_red_smaller = [-0.2223, -0.2338, -0.2654]
wsb_red_smaller = [0.0006067, 0.0009791, 0.002236]
wdq_blue_smaller = [4.2931, 4.2931, 4.2668]
shift_blue_smaller = [-0.1909, -0.2069, -0.2332]
wsb_blue_smaller = [0.0008969, 0.001981]
Omfac_smaller = [1, 1.5, 2, 3]
Omegaq_smaller = 0.025*np.asarray(Omfac_smaller)
Omegac_smaller = 0.317*np.asarray(Omfac_smaller)
power_smaller = 2*np.asarray(Omegaq_smaller)**2 + 2*np.asarray(Omegac_smaller)**2

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
fig.suptitle("Transmon, double-tone, $\\Omega_q/2/2\\pi = (0.025 \\rightarrow) (0.038 \\rightarrow) 0.05 \\rightarrow 0.075$ GHz")
plt.subplot(1, 2, 1)
plt.scatter(shift_red_larger, wsb_red_larger, marker='s', c='r', s=20*np.asarray(Omfac_larger))
plt.scatter(shift_blue_larger, wsb_blue_larger, marker='s', c='b', s=20*np.asarray(Omfac_larger))
plt.scatter(shift_red_smaller, wsb_red_smaller, marker='o', c='r', s=20*np.asarray(Omfac_smaller)[1:])
plt.scatter(shift_blue_smaller[1:], wsb_blue_smaller, marker='o', c='b', s=20*np.asarray(Omfac_smaller)[1:])
plt.plot(shift_red_larger, wsb_red_larger, c='r')
plt.plot(shift_blue_larger, wsb_blue_larger, c='b', label='$\\omega_q > \\omega_c$')
plt.plot(shift_red_smaller, wsb_red_smaller, ':', c='r')
plt.plot(shift_blue_smaller[1:], wsb_blue_smaller, ':', c='b', label='$\\omega_q < \\omega_c$')
plt.ylim([0, 0.008])
plt.xlabel("ac-Stark shift [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.legend()

plt.subplot(1, 2, 2)
plt.scatter(wdq_red_larger, wsb_red_larger, marker='s', c='r', s=20*np.asarray(Omfac_larger))
plt.scatter(wdq_blue_larger, wsb_blue_larger, marker='s', c='b', s=20*np.asarray(Omfac_larger))
plt.scatter(wdq_red_smaller, wsb_red_smaller, marker='o', c='r', s=20*np.asarray(Omfac_smaller)[1:])
plt.scatter(wdq_blue_smaller[1:], wsb_blue_smaller, marker='o', c='b', s=20*np.asarray(Omfac_smaller)[1:])
plt.plot(wdq_red_larger, wsb_red_larger, c='r')
plt.plot(wdq_blue_larger, wsb_blue_larger, c='b', label='$\\omega_q > \\omega_c$')
plt.plot(wdq_red_smaller, wsb_red_smaller, ':', c='r')
plt.plot(wdq_blue_smaller[1:], wsb_blue_smaller, ':', c='b', label='$\\omega_q < \\omega_c$')
plt.ylim([0, 0.008])
plt.xlabel("$\\Omega_q/2\\pi$ [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.legend()

plt.tight_layout()
fig.subplots_adjust(top=0.88)
plt.show()

fig, axes = plt.subplots(1, 4, figsize=(12, 4))
plt.subplot(1, 4, 1)
plt.plot(Omegaq_larger, wsb_red_larger, c='r')
plt.plot(Omegaq_larger, wsb_blue_larger, c='b', label='$\\omega_q > \\omega_c$')
plt.plot(Omegaq_smaller[1:], wsb_red_smaller, ':', c='r')
plt.plot(Omegaq_smaller[2:], wsb_blue_smaller, ':', c='b', label='$\\omega_q < \\omega_c$')
plt.xlim([0.02, 0.08])
plt.ylim([0, 0.0072])
plt.xlabel("$\\omega_q/2/2\\pi$ [GHz]")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Amplitude vs. transition frequency")
plt.legend()

plt.subplot(1, 4, 2)
plt.plot(power_larger, wsb_red_larger, c='r')
plt.plot(power_larger, wsb_blue_larger, c='b')
plt.plot(power_smaller[1:], wsb_red_smaller, ':', c='r')
plt.plot(power_smaller[2:], wsb_blue_smaller, ':', c='b')
plt.xlim([0, 2])
plt.ylim([0, 0.0072])
plt.xlabel("$P$")
plt.ylabel("$\\Omega_{{sb}}/2\\pi$ [GHz]")
plt.title("Power vs. transition frequency")

plt.subplot(1, 4, 3)
plt.plot(Omegaq_larger, shift_red_larger, c='r')
plt.plot(Omegaq_larger, shift_blue_larger, c='b')
plt.plot(Omegaq_smaller[1:], shift_red_smaller, ':', c='r')
plt.plot(Omegaq_smaller[1:], shift_blue_smaller, ':', c='b')
plt.xlim([0.02, 0.08])
plt.ylim([-0.28, -0.14])
plt.xlabel("$\\Omega_q/2/2\\pi$ [GHz]")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Amplitude vs. ac-Stark shift")

plt.subplot(1, 4, 4)
plt.plot(power_larger, shift_red_larger, c='r')
plt.plot(power_larger, shift_blue_larger, c='b')
plt.plot(power_smaller[1:], shift_red_smaller, ':', c='r')
plt.plot(power_smaller[1:], shift_blue_smaller, ':', c='b')
plt.xlim([0, 2])
plt.ylim([-0.28, -0.14])
plt.xlabel("$P$")
plt.ylabel("ac-Stark shift [GHz]")
plt.title("Power vs. ac-Stark shift")

plt.tight_layout()
plt.show()
