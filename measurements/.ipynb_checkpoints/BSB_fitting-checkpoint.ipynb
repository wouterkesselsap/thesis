# %% [markdown]
# # Notebook to fit free parameters within a model to data.

# %%
import stlab
import stlabutils
import numpy as np
import pickle
import multiprocessing as mp
import matplotlib.pyplot as plt

from numpy import tan, pi, sqrt
from numpy.fft import fft, ifft
from scipy.optimize import minimize, curve_fit
from scipy.constants import e,h,hbar,k,G,epsilon_0
from lmfit import Model, Parameters
phi_0 = hbar/2./e
# import numdifftools
import matplotlib.pyplot as plt
# %matplotlib inline
from qutip import *
qutip.settings.has_mkl=False
from scipy import signal
import matplotlib as mpl
mpl.rcParams['axes.linewidth'] = 2
# Out:
# Warning: Missing dependencies for autodetect_instrument! Autodetect routines not imported.

# %%
# 12 dBm: W_top_2020_01_15_17.30.32_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_12/W_top_2020_01_15_17.30.32_Omegad_12.dat
# 10 dBm: W_top_2020_01_15_15.39.25_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_10/W_top_2020_01_15_15.39.25_Omegad_10.dat
# 5 dBm: W_top_2020_01_20_19.32.00_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_5/W_top_2020_01_20_19.32.00_Omegad_5.dat
# 3 dBm: W_top_2020_01_20_17.40.53_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_3/W_top_2020_01_20_17.40.53_Omegad_3.dat
# 1 dBm: W_top_2020_01_10_16.20.43_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_1/W_top_2020_01_10_16.20.43_Omegad_1.dat
# 0 dBm: W_top_2020_01_13_13.40.26_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_0/W_top_2020_01_13_13.40.26_Omegad_0.dat
# -1 dBm: W_top_2020_01_10_18.11.50_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_-1/W_top_2020_01_10_18.11.50_Omegad_-1.dat
# -2 dBm: W_top_2020_01_13_15.31.33_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_-2/W_top_2020_01_13_15.31.33_Omegad_-2.dat
# -3 dBm: W_top_2020_01_10_20.02.57_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_-3/W_top_2020_01_10_20.02.57_Omegad_-3.dat
# -4 dBm: W_top_2020_01_13_17.22.40_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_-4/W_top_2020_01_13_17.22.40_Omegad_-4.dat
# -5 dBm: W_top_2020_01_10_21.54.08_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_-5/W_top_2020_01_10_21.54.08_Omegad_-5.dat
# -6 dBm: W_top_2020_01_13_19.13.47_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_-6/W_top_2020_01_13_19.13.47_Omegad_-6.dat
# -7 dBm: W_top_2020_01_10_23.45.15_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_-7/W_top_2020_01_10_23.45.15_Omegad_-7.dat
# -8 dBm: W_top_2020_01_13_21.04.58_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_-8/W_top_2020_01_13_21.04.58_Omegad_-8.dat
# -9 dBm: W_top_2020_01_11_01.36.22_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_-9/W_top_2020_01_11_01.36.22_Omegad_-9.dat
# -10 dBm: W_top_2020_01_13_22.56.09_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_-10/W_top_2020_01_13_22.56.09_Omegad_-10.dat
# -12 dBm: W_top_2020_01_21_17.13.25_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_-12/W_top_2020_01_21_17.13.25_Omegad_-12.dat

# %% [markdown]
# # Select data

# %%
# Specify the path to your data file
folder = '/home/jovyan/steelelab/measurement_data/newBF/Wouter/Wouter_spectra_around_resonant_condition/'
file = 'W_ls_2020_01_14_12.15.12_Resonator_split_Singletone-sideband-LT142W4_5D_C_60dB_Omegad_1/W_ls_2020_01_14_12.15.12_Omegad_1.dat'
filepath = folder + file

# Load the data
data = stlabutils.readdata.readdat(filepath)

#Create new data column if needed
for line in data:
    line['S21_lin ()'] = (line['S21re ()']**2 + line['S21im ()']**2)

# Specify what data you want to use for the parameter fitting
block = data[40]
xdata = np.asarray(block['Frequency (Hz)'])
ydata = np.asarray(block['S21_lin ()'])
# Out:
# ['Frequency (Hz)', 'S21re ()', 'S21im ()', 'S21dB (dB)', 'S21Ph (rad)', 'Power (dBm)']

# %% [markdown]
# # Visualize the data

# %%
plt.figure()
plt.plot(xdata, ydata,'ro', label='Data', alpha=0.5)
plt.xlabel("$f$ [Hz]")
plt.ylabel("Transmission")
plt.legend()
plt.show()

# %% [markdown]
# # Model
# Here we specify the model to be optimized.
# The model is given as a function with
# - the first argument: the x-coordinates (frequencie range)
# - the other arguments: the parameters to be fitted.
#
# All fixed parameters should be given inside the function as local variables or outside the function as global variables.
#
# If you want other parameters to be fitted, just change the arguments inside the function definition.
# If you have multiple models, which require different fixed parameters, I can recommend you to define them inside a model function locally.

# %%
def spectroscopy(wp_list, g, A, B,  gamma ,detun, dwc):
    # Fixed variables
    
    # Cavity (b)
    wc = 4.0753e9
    wc += dwc
    kappa = 10e6
    Nh_spec = 3
    chi = 1e+6
    
    # Qubit (a)
#     wq = 2*pi*4.0757e9
    wq = 6e9
    Aq = 138e6
#     gamma = 100e3 ##homogenous linewidth
    gamma_phi = 0e3 ##inhomogenous linewidth
    Nl_spec = 4
    eps = 116.3e3
    
    g = 2*pi*g
    chi = 2*pi*chi
    wq  = 2*pi*wq
    wc  = 2*pi*wc
    gamma = 2*pi*gamma
    gamma_phi = 2*pi*gamma_phi
    Aq = 2*pi*Aq
    kappa = 2*pi*kappa
    wp_list = wp_list*2*pi
    eps = 2*pi*eps
    
    # Hamiltonian
    a = tensor(destroy(Nl_spec), qeye(Nh_spec))
    b = tensor(qeye(Nl_spec), destroy(Nh_spec))
    num_b = b.dag()*b
    num_a = a.dag()*a
    r=[]
    H0 = wq*num_a + wc*num_b - 0.5*Aq*a.dag()*a.dag()*a*a - g*(a.dag()*b.dag() + b*a)
    #    qubit      cavity     anharmonicity                coupling
    
    # Calculate spectrum
    for wp in wp_list:
        H = H0 - (wc+wq-wp-detun)*num_a - wp*num_b + eps*1j*(b.dag()-b) - 2*chi*num_a*num_b
        #        drive      drive      drive                state-dependent frequency shift
        c_ops = [np.sqrt(gamma)*a, np.sqrt(gamma_phi)*num_a, np.sqrt(kappa)*b]  
        rho_ss = steadystate(H, c_ops)  ## steady-state since interested in f-domain
        r.append([np.absolute(expect(b,rho_ss))**2])
    
    out = A*np.array(r) + B
    return np.concatenate(out)

# %% [markdown]
# # Initial guess
# The computer must know where to start searching for a minimum in the error function. So here we determine the initial guess of the parameters, the frequency range to compute the model for, and we plot the initial guess.

# %%
g = 1694221.47  #coupling constant
A = 4.3507e-05
B = -2.2716e-10
# eps = 166e3
# wc = 4.0755e9
detun = 10393729.6
gamma = 143922.352
# gamma_phi = 200e3
dwc = 848007.422

# initguess = spectroscopy(xdata, g, A, B,gamma, detun)
w_points = 200
wp_list = np.linspace(xdata[0],xdata[-1],w_points)#Hz
initguess = spectroscopy(wp_list, g, A, B,gamma, detun, dwc)

# %%
plt.figure()
plt.plot(xdata, ydata,'ro', alpha=0.5, label='Data')
plt.plot(wp_list, initguess,'b-', label='Initial guess')
# plt.xlim(4.073e9,4.077e9)
plt.title('Title')
plt.xlabel('Frequency (Hz)')  
plt.ylabel('Transmission') 
plt.show()
plt.close()

# %%
data = {'x' : wp_list, 'y' : initguess}
outfile = open('/home/jovyan/jupyterhub-shared/Wouter/BSB_fit.dat', 'wb')
pickle.dump(data, outfile)
outfile.close()

# %%
##### plt.figure()
# plt.plot(xdata, ydata,'ro', alpha=0.5, label='Data')
plt.plot(xdata, 10*initguess1,'r-', label='Initial guess')
plt.plot(xdata, initguess2,'b-', label='Initial guess')
plt.title('Title')
plt.xlabel('Frequency (Hz)')  
plt.ylabel('Transmission') 
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-f0446cf30e2d> in <module>
#       1 ##### plt.figure()
#       2 # plt.plot(xdata, ydata,'ro', alpha=0.5, label='Data')
# ----> 3 plt.plot(xdata, 10*initguess1,'r-', label='Initial guess')
#       4 plt.plot(xdata, initguess2,'b-', label='Initial guess')
#       5 plt.title('Title')
#
# NameError: name 'xdata' is not defined

# %% [markdown]
# # Fitting
# Now it's time to look at the fitting methods.
# There are two options in this notebook:
# - Sequential gradient descent, developed by Wouter Kessels.
# - Built-in methods from lmfit and SciPy

# %% [markdown]
# ## A. Sequential gradient descent
# The basic intuitive workflow is that it takes steps of a predefined size for each of the to be fitted variables. It continues for one variable, holding the other variables fixed, until it hits a minimum in the cost function. Subsequently it continues for the next variable. The fitting is done when a local minimum in the cost function is hit for all variables. Note that a smaller step size will increase the accuracy of the result, but the calculation time might increase dramatically as well, because the workflow is still a rigorous, unadaptive search.
#
# The workflow and costfunction (squared error) are defined below.

# %%
costfun = lambda x1, x2 : sum(abs(x1 - x2)**2)

def sgd(x, ydata, model, costfun, p0, step):
    """Sequential gradient decent over all parameters of the model function.
    The basic intuitive workflow is that it takes steps of a predefined size
    for each of the to be fitted variables. It continues for one variable,
    holding the other variables fixed, until it hits a minimum in the cost
    function. Subsequently it continues for the next variable. The fitting is
    done when a local minimum in the cost function is hit for all variables.
    
    Note that a smaller step size will increase the accuracy of the result,
    but the calculation time might increase dramatically as well.
    
    Input
    -----
    x : array-like
        x-data
    ydata : array-like
        Experimental data corresponding to the x-coordinates
    model : function
        Model function with N variables
    costfun : function
        Cost function
    p0 : array-like
        Initial guess of N variables
    step : array-like
        Step size for each of N variables
    
    Returns
    -------
    paramvals : array-like
        Fitted values of the N variables
    """
    from copy import copy
    finish = False
    paramvals = copy(p0)
    sim_init = model(x, p0[0], p0[1], p0[2], p0[3])
    cost = costfun(ydata, sim_init)
    while not finish:
        changes = [False, False, False, False]
        for ipar in range(len(paramvals)):
            argsmin = copy(paramvals)
            argsmin[ipar] = paramvals[ipar] - step[ipar]
            if argsmin[ipar] < 0:
                argsmin[ipar] = 0
            argsplus = copy(paramvals)
            argsplus[ipar] = paramvals[ipar] + step[ipar]
            
            simmin = model(x, argsmin[0], argsmin[1], argsmin[2], argsmin[3])
            simplus = model(x, argsplus[0], argsplus[1], argsplus[2], argsplus[3])
            
            costmin = costfun(ydata, simmin)
            costplus = costfun(ydata, simplus)
            smallest = min([costmin, costplus])
            
            if (smallest == costmin and smallest < cost):
                stepdir = -step[ipar]
                paramvals[ipar] -= step[ipar]
                cost = copy(costmin)
                changes[ipar] = True
            elif (smallest == costplus and smallest < cost):
                stepdir = step[ipar]
                paramvals[ipar] += step[ipar]
                cost = copy(costplus)
                changes[ipar] = True
            elif (smallest > cost):
                stepdir = 0
            
            print(paramvals, cost)
            
            if stepdir != 0:
                descending = True
                while descending:
                    args = copy(paramvals)
                    args[ipar] += stepdir
                    if args[ipar] < 0:
                        args[ipar] = 0
                        descending = False
                    sim = model(x, args[0], args[1], args[2], args[3])
                    newcost = costfun(ydata, sim)
                    if newcost <= cost:
                        paramvals[ipar] = args[ipar]
                        cost = copy(newcost)
                    elif newcost > cost:
                        descending = False
                    
                    print(paramvals, cost)
            
        if True not in changes:
            finish = True
            print("Finished at local minimum")
    
    return paramvals

# %% [markdown]
# Execute the sequential gradient descent on the model and print the result together with the initial guess.

# %%
fitted_vals = sgd(xdata, ydata, spectroscopy, costfun,
                  p0=[g, power, A, B], step=[1e4, 1, 1e-7, 1e-10])
print(vals)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-509-32f0053f38ca> in <module>
#       1 fitted_vals = sgd(xdata, ydata, spectroscopy, costfun,
# ----> 2                   p0=[g, power, A, B], step=[1e4, 1, 1e-7, 1e-10])
#       3 print(vals)
#
# NameError: name 'power' is not defined

# %%
bestfit = spectroscopy(xdata, vals[0], vals[1], vals[2], vals[3], vals[4])

plt.figure()
plt.plot(xdata, ydata,'ro', alpha=0.6, label="Data")
plt.plot(xdata, initguess, 'k-', label='Initial guess')
plt.plot(xdata, bestfit, 'b-', label='SGD')
plt.xlabel('Readout frequency (Hz)')  
plt.ylabel('Transmission')
plt.legend()
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-510-af59b0968a21> in <module>
# ----> 1 bestfit = spectroscopy(xdata, vals[0], vals[1], vals[2], vals[3], vals[4])
#       2
#       3 plt.figure()
#       4 plt.plot(xdata, ydata,'ro', alpha=0.6, label="Data")
#       5 plt.plot(xdata, initguess, 'k-', label='Initial guess')
#
# NameError: name 'vals' is not defined

# %% [markdown]
# ## B. lmfit's methods
# The lmfit package contains dozens of Scipy-based methods to do parameter fitting. Every method has its own characteristics, some are fast, some are rigorous, some provide error estimates. You can just try different models and see which one gives the best result. The available models can be found on this page: https://lmfit.github.io/lmfit-py/fitting.html.
#
# The resulting fits are written to a pickle file so that they are kept accessible for later times.

# %% [markdown]
# ### 1. Least-squares

# %%
smodel = Model(spectroscopy)
result_leastsq = smodel.fit(ydata, wp_list=xdata, g=g, A=A, B=B ,gamma=gamma, detun=detun, dwc=dwc, nan_policy='omit',
                            method='leastsq')
# result_leastsq = smodel.fit(ydata, wd_list=xdata, g=g, A=A, B=B ,gamma=gamma,gamma_phi=gamma_phi, detun=detun, nan_policy='omit',
#                             method='leastsq')
print(result_leastsq.fit_report())

plt.plot(xdata, ydata, 'bo', alpha=0.5)
plt.plot(xdata, result_leastsq.best_fit, 'r-', label='Best')
plt.plot(xdata, result_leastsq.init_fit, 'g-', label='Initial')
plt.legend()
plt.show()
# Out:
# [[Model]]
#     Model(spectroscopy)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 36
#     # data points      = 301
#     # variables        = 6
#     chi-square         = 3.0819e-16
#     reduced chi-square = 1.0447e-18
#     Akaike info crit   = -12456.3036
#     Bayesian info crit = -12434.0609
# [[Variables]]
#     g:      1694221.47 +/- 20142.9936 (1.19%) (init = 2000000)
#     A:      4.3507e-05 +/- 4.5747e-07 (1.05%) (init = 5e-05)
#     B:     -2.2716e-10 +/- 1.0832e-10 (47.69%) (init = 2e-10)
#     gamma:  143922.352 +/- 15921.8516 (11.06%) (init = 200000)
#     detun:  10393729.6 +/- 383026.897 (3.69%) (init = 7000000)
#     dwc:    848007.422 +/- 49330.7297 (5.82%) (init = 500000)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(detun, dwc)   =  0.970
#     C(A, B)         = -0.823
#     C(gamma, detun) = -0.688
#     C(gamma, dwc)   = -0.614
#     C(A, gamma)     =  0.488
#     C(A, detun)     = -0.360
#     C(A, dwc)       = -0.324
#     C(g, gamma)     =  0.311
#     C(B, gamma)     = -0.258
#     C(B, detun)     =  0.190
#     C(B, dwc)       =  0.170
#     C(g, dwc)       = -0.169
#     C(g, detun)     = -0.154
#     C(g, A)         =  0.132

# %%
plt.plot(xdata, ydata, 'bo', alpha=0.5)
plt.xlim(4.074e9,4.077e9)
plt.plot(xdata, result_leastsq.best_fit, 'r-', label='Best')
plt.plot(xdata, result_leastsq.init_fit, 'g-', label='Initial')
plt.legend()
plt.show()

# %% [markdown]
# ### 2. L-BFGS-B
# https://en.wikipedia.org/wiki/Limited-memory_BFGS

# %%
smodel = Model(spectroscopy)
result_lbfgsb = smodel.fit(ydata, wd_list=xdata, g=g, A=A,B=B,detun=detun, nan_policy='omit',
                           method='lbfgsb')
print(result_lbfgsb.fit_report())

plt.plot(xdata, ydata, 'bo', alpha=0.5)
plt.plot(xdata, result_lbfgsb.best_fit, 'r-', label='Best')
plt.plot(xdata, result_lbfgsb.init_fit, 'g-', label='Initial')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-30-51c393c9f0ec> in <module>
#       1 smodel = Model(spectroscopy)
#       2 result_lbfgsb = smodel.fit(ydata, wd_list=xdata, g=g, A=A,B=B,detun=detun, nan_policy='omit',
# ----> 3                            method='lbfgsb')
#       4 print(result_lbfgsb.fit_report())
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\model.py in fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, nan_policy, **kwargs)
#     871                              scale_covar=scale_covar, fcn_kws=kwargs,
#     872                              nan_policy=self.nan_policy, **fit_kws)
# --> 873         output.fit(data=data, weights=weights)
#     874         output.components = self.components
#     875         return output
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\model.py in fit(self, data, params, weights, method, nan_policy, **kwargs)
#    1214         self.userargs = (self.data, self.weights)
#    1215         self.userkws.update(kwargs)
# -> 1216         self.init_fit = self.model.eval(params=self.params, **self.userkws)
#    1217         _ret = self.minimize(method=self.method)
#    1218
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\model.py in eval(self, params, **kwargs)
#     702
#     703         """
# --> 704         return self.func(**self.make_funcargs(params, kwargs))
#     705
#     706     @property
#
# <ipython-input-17-f47609054ec1> in spectroscopy(wd_list, g, A, B, eps, detun)
#      66         #        drive      drive      drive                state-dependent frequency shift
#      67         c_ops = [np.sqrt(gamma)*a, np.sqrt(gamma_phi)*num_a, np.sqrt(kappa)*b]
# ---> 68         rho_ss = steadystate(H, c_ops)  ## steady-state since interested in f-domain
#      69         r.append([expect(b.dag()*b,rho_ss)])
#      70
#
# C:\ProgramData\Anaconda3\lib\site-packages\qutip\steadystate.py in steadystate(A, c_op_list, method, solver, **kwargs)
#     288         if (ss_args['solver'] == 'scipy' and ss_args['sparse']) \
#     289                 or ss_args['solver'] == 'mkl':
# --> 290             return _steadystate_direct_sparse(A, ss_args)
#     291         else:
#     292             return _steadystate_direct_dense(A, ss_args)
#
# C:\ProgramData\Anaconda3\lib\site-packages\qutip\steadystate.py in _steadystate_direct_sparse(L, ss_args)
#     435         lu = splu(L, permc_spec=ss_args['permc_spec'],
#     436                   diag_pivot_thresh=ss_args['diag_pivot_thresh'],
# --> 437                   options=dict(ILU_MILU=ss_args['ILU_MILU']))
#     438         v = lu.solve(b)
#     439         _direct_end = time.time()
#
# ~\AppData\Roaming\Python\Python36\site-packages\scipy\sparse\linalg\dsolve\linsolve.py in splu(A, permc_spec, diag_pivot_thresh, relax, panel_size, options)
#     309         _options.update(options)
#     310     return _superlu.gstrf(N, A.nnz, A.data, A.indices, A.indptr,
# --> 311                           ilu=False, options=_options)
#     312
#     313
#
# RuntimeError: Factor is exactly singular

# %% [markdown]
# ### 3. Nelder-Mead
# https://en.wikipedia.org/wiki/Nelder%E2%80%93Mead_method

# %%
smodel = Model(spectroscopy)
result_nelder = smodel.fit(ydata, wd_list=xdata, g=g, A=A,B=B,wc=wc,detun=detun, nan_policy='omit',
                           method='nelder')
print(result_nelder.fit_report())

plt.plot(xdata, ydata, 'bo', alpha=0.5)
plt.plot(xdata, result_nelder.best_fit, 'r-', label='Best')
plt.plot(xdata, result_nelder.init_fit, 'g-', label='Initial')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-28-949d4c5764bc> in <module>
#       1 smodel = Model(spectroscopy)
#       2 result_nelder = smodel.fit(ydata, wd_list=xdata, g=g, A=A,B=B,wc=wc,detun=detun, nan_policy='omit',
# ----> 3                            method='nelder')
#       4 print(result_nelder.fit_report())
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\model.py in fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, nan_policy, **kwargs)
#     871                              scale_covar=scale_covar, fcn_kws=kwargs,
#     872                              nan_policy=self.nan_policy, **fit_kws)
# --> 873         output.fit(data=data, weights=weights)
#     874         output.components = self.components
#     875         return output
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\model.py in fit(self, data, params, weights, method, nan_policy, **kwargs)
#    1214         self.userargs = (self.data, self.weights)
#    1215         self.userkws.update(kwargs)
# -> 1216         self.init_fit = self.model.eval(params=self.params, **self.userkws)
#    1217         _ret = self.minimize(method=self.method)
#    1218
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\model.py in eval(self, params, **kwargs)
#     702
#     703         """
# --> 704         return self.func(**self.make_funcargs(params, kwargs))
#     705
#     706     @property
#
# <ipython-input-17-f47609054ec1> in spectroscopy(wd_list, g, A, B, eps, detun)
#      66         #        drive      drive      drive                state-dependent frequency shift
#      67         c_ops = [np.sqrt(gamma)*a, np.sqrt(gamma_phi)*num_a, np.sqrt(kappa)*b]
# ---> 68         rho_ss = steadystate(H, c_ops)  ## steady-state since interested in f-domain
#      69         r.append([expect(b.dag()*b,rho_ss)])
#      70
#
# C:\ProgramData\Anaconda3\lib\site-packages\qutip\steadystate.py in steadystate(A, c_op_list, method, solver, **kwargs)
#     288         if (ss_args['solver'] == 'scipy' and ss_args['sparse']) \
#     289                 or ss_args['solver'] == 'mkl':
# --> 290             return _steadystate_direct_sparse(A, ss_args)
#     291         else:
#     292             return _steadystate_direct_dense(A, ss_args)
#
# C:\ProgramData\Anaconda3\lib\site-packages\qutip\steadystate.py in _steadystate_direct_sparse(L, ss_args)
#     435         lu = splu(L, permc_spec=ss_args['permc_spec'],
#     436                   diag_pivot_thresh=ss_args['diag_pivot_thresh'],
# --> 437                   options=dict(ILU_MILU=ss_args['ILU_MILU']))
#     438         v = lu.solve(b)
#     439         _direct_end = time.time()
#
# ~\AppData\Roaming\Python\Python36\site-packages\scipy\sparse\linalg\dsolve\linsolve.py in splu(A, permc_spec, diag_pivot_thresh, relax, panel_size, options)
#     309         _options.update(options)
#     310     return _superlu.gstrf(N, A.nnz, A.data, A.indices, A.indptr,
# --> 311                           ilu=False, options=_options)
#     312
#     313
#
# RuntimeError: Factor is exactly singular

# %% [markdown]
# ### 4. Powell
# https://en.wikipedia.org/wiki/Powell%27s_method

# %%
smodel = Model(spectroscopy)
result_powell = smodel.fit(ydata, wd_list=xdata, A=A,B=B,detun=detun, nan_policy='omit',
                           method='powell')
print(result_powell.fit_report())

plt.plot(xdata, ydata, 'bo', alpha=0.5)
plt.plot(xdata, result_powell.best_fit, 'r-', label='Best')
plt.plot(xdata, result_powell.init_fit, 'g-', label='Initial')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-29-a019cfeec30f> in <module>
#       1 smodel = Model(spectroscopy)
#       2 result_powell = smodel.fit(ydata, wd_list=xdata, A=A,B=B,detun=detun, nan_policy='omit',
# ----> 3                            method='powell')
#       4 print(result_powell.fit_report())
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\model.py in fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, nan_policy, **kwargs)
#     871                              scale_covar=scale_covar, fcn_kws=kwargs,
#     872                              nan_policy=self.nan_policy, **fit_kws)
# --> 873         output.fit(data=data, weights=weights)
#     874         output.components = self.components
#     875         return output
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\model.py in fit(self, data, params, weights, method, nan_policy, **kwargs)
#    1214         self.userargs = (self.data, self.weights)
#    1215         self.userkws.update(kwargs)
# -> 1216         self.init_fit = self.model.eval(params=self.params, **self.userkws)
#    1217         _ret = self.minimize(method=self.method)
#    1218
#
# C:\ProgramData\Anaconda3\lib\site-packages\lmfit\model.py in eval(self, params, **kwargs)
#     702
#     703         """
# --> 704         return self.func(**self.make_funcargs(params, kwargs))
#     705
#     706     @property
#
# <ipython-input-17-f47609054ec1> in spectroscopy(wd_list, g, A, B, eps, detun)
#      66         #        drive      drive      drive                state-dependent frequency shift
#      67         c_ops = [np.sqrt(gamma)*a, np.sqrt(gamma_phi)*num_a, np.sqrt(kappa)*b]
# ---> 68         rho_ss = steadystate(H, c_ops)  ## steady-state since interested in f-domain
#      69         r.append([expect(b.dag()*b,rho_ss)])
#      70
#
# C:\ProgramData\Anaconda3\lib\site-packages\qutip\steadystate.py in steadystate(A, c_op_list, method, solver, **kwargs)
#     288         if (ss_args['solver'] == 'scipy' and ss_args['sparse']) \
#     289                 or ss_args['solver'] == 'mkl':
# --> 290             return _steadystate_direct_sparse(A, ss_args)
#     291         else:
#     292             return _steadystate_direct_dense(A, ss_args)
#
# C:\ProgramData\Anaconda3\lib\site-packages\qutip\steadystate.py in _steadystate_direct_sparse(L, ss_args)
#     435         lu = splu(L, permc_spec=ss_args['permc_spec'],
#     436                   diag_pivot_thresh=ss_args['diag_pivot_thresh'],
# --> 437                   options=dict(ILU_MILU=ss_args['ILU_MILU']))
#     438         v = lu.solve(b)
#     439         _direct_end = time.time()
#
# ~\AppData\Roaming\Python\Python36\site-packages\scipy\sparse\linalg\dsolve\linsolve.py in splu(A, permc_spec, diag_pivot_thresh, relax, panel_size, options)
#     309         _options.update(options)
#     310     return _superlu.gstrf(N, A.nnz, A.data, A.indices, A.indptr,
# --> 311                           ilu=False, options=_options)
#     312
#     313
#
# RuntimeError: Factor is exactly singular
